# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

fig1 = sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
fig1.savefig('linear_regression_seaborn.png', dpi =300)
